# %%
import seaborn as sns
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import zipfile
import re as re

# %%
df = pd.read_csv("rotterdam_real_estate.csv")
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.head()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (34,50,51,52,54,55,56,57,60,62,63,65,66,67,68,70,71,77,80,81,82,84,88,91,94,95,96,97,98,99,106,107,108,109,112,113,114,115,117,118,120,121,124,128,129,130,131,133,134,135,136,137,138,139,140,141,142,143,144,145,146,147,148,149,150,151,152,153,154,155,156,157,158,159,160,162,163,164,166,167,168,169,171,172,175,176,177,178,179,180,182,183,184,186,187,188,189,190,191,193,194,195,196,198,200,201,203,204,205,208,210,211,212,214,215,216,217,218,219,220,221,222,223,225,226,227,228,229,230,231,232,233,234,235,236,237,239,240,241,242,244,246,247,248,249,250,251,252,253,254,255,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,282,283,284,285,288,290,291,292,293,294,295,296,297,298,299,300,301,302,303,304,306,307,308,309,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,339,342,343,344,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,363,364,365,366,367,368,369,370,371,372,373,374,375,377,379,380,381,382,383,384,385,386,387,388,389,390,391,392,393,394,395,396,397,398,399,400,401,402,403,404,405,406,407,408,409,410,411,412,413,414,415,416,417,418,419,420,421,422,423,424,425,426,427,428,429,430,431,432,433,434,435,436,437,438,439,440,441,442,443,444,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506,507,508,509,510,511,512,513,514,515,516,517,518,519,520,521,522,523,524,525,526,527,528,529,530,531,532,533,534,535,536,537,538,539,540,541,542,543,544,545,546,547,548,549,550,551,552,553,554,555,556,557,558,559,560,561,562,563,564,565,566,567,568,569,570,571,572,573,574,575,576,577,578,579,580,581,582,583,584,585,586,587,588,589,590,591,592,593,594,595,596,597,598,599,600,601,602,603,604,605,606,607,608,609,610,611,612,613,614,615,616,617,618,619,620,621,622,623,624,625,626,627,628,629,630,631,632,633,634,635,636,637,638,639,640,641,642,643,644,645,646,647,648,649,650,651,652,653,654,655,656,657,658,659,660,661,662,663,664,665,666,667,668,669,670,671,672,673,674,675,676,677,678,679,680,681,682,683,684,685,686,687,688,689,690,691,692,693,694,695,696,697,698,699,700,701,702,703,704,705,706,707,708,709,710,711,712,713,714,715,716,717,718,719,720,721,722,723,724,725,726,727,728,729,730,731,732,733,734,735,736,737,738,739,740,741,742,743,744,745,746,747,748,749,750,751,752,753,754,755,756,757,758,759,760,761,762,763,764,765,766,767,768,769,770,771,772,773,774,775,776,777,778,779,780,781,782,783,784,785,786,787,788,789,790,791,792,793,794,795,796,797,798,799,800,801,802,803,804,805,806,807,808,809,810,811,812,813,814,815,816,817,818,819,820,821,822,823,824,825,826,827,828,829,830,831,832,833,834,835,836,837,838,839,840,841,842,843,844,845,846,847,848,849,850,851,852,853,854,855,856,857,858,859,860,861,862,863,864,865,866,867,868,869,870,871,872,873,874,875,876,877,878,879,880,881,882,883,884,885,886,887,888,889,890,891,892,893,894,895,896,897,898,899,900,901,902,903,904,905,906,907,908,909,910,911,912,913,914,915,916,917,918,919,920,921,922,923,924,925,926,927,928,929,930,931,932,933,934,935,936,937,938,939,940,941,942,943,944,945,946,947,948,949,950,951,952,953,954,955,956,957,958,959,960,961,962,963,964,965,966,967,968,969,970,971,972,973,974,975,976,977,978,979,980,981,982,983,984,985,986,987,988,989,990,991,992,993,994,995,996,997,998,999,1000,1001,1002,1003,1004,1005,1006,1007,1008,1009,1010,1011,1012,1013,1014,1015,1016,1017,1018,1019,1020,1021,1022,1023,1024,1025,1026,1027,1028,1029,1030,1031,1032,1033,1034,1035,1036,1037,1038,1039,1040,1041,1042,1043,1044,1045,1046,1047,1048,1049,1050,1051,1052,1053,1054,1055,1056,1057,1058,1059,1060,1061,1062,1063,1064,1065,1066,1067,1068,1069,1070,1071,1072,1073,1074,1075,1076,1077,1078,1079,1 ...
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                   Acceptance Annual meeting              Asking price  \
# 0  Available in consultation             No    € 415,000 kosten koper
# 1  Available in consultation            NaN    € 505,000 vrij op naam
# 2  Available in consultation            Yes  € 1,000,000 kosten koper
# 3  Available in consultation            NaN  € 1,098,000 kosten koper
# 4  Available in consultation            NaN    € 417,000 vrij op naam
#
#   Asking price per m² Building insurance    Building type  \
# 0             € 3,402                 No  Resale property
# 1             € 6,733                NaN     New property
# 2             € 5,682                Yes  Resale property
# 3             € 5,779                NaN  Resale property
# 4             € 5,024                NaN     New property
#
#              Energy label Exterior space attached to the building  \
# 0  A What does this mean?                                   17 m²
# 1                     NaN                                   12 m²
# 2  A What does this mean?                                     NaN
# 3  G What does this mean?                                   10 m²
# 4                     NaN                                     NaN
#
#                                           Facilities  \
# 0            Mechanical ventilation and sliding door
# 1                                           Elevator
# 2  Alarm installation, elevator, mechanical venti...
# 3                                        Electricity
# 4                                                NaN
#
#                                       Garden  ... 8 rooms (7 bedrooms) 937 m³  \
# 0                                Sun terrace  ...                  NaN    NaN
# 1                                        NaN  ...                  NaN    NaN
# 2                                        NaN  ...                  NaN    NaN
# 3  Back garden, front garden and side garden  ...                  NaN    NaN
# 4                                        NaN  ...                  NaN    NaN
#
#   Alongside water and in residential district 585 m²  \
# 0                                         NaN    NaN
# 1                                         NaN    NaN
# 2                                         NaN    NaN
# 3                                         NaN    NaN
# 4                                         NaN    NaN
#
#   Alongside a quiet road, sheltered location, outside the built-up area and unobstructed surrounding view  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Complete floor heating and heat pump  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   266 m² (14 meter deep and 19 meter broad) 277 m² Before 1906  \
# 0                                       NaN    NaN         NaN
# 1                                       NaN    NaN         NaN
# 2                                       NaN    NaN         NaN
# 3                                       NaN    NaN         NaN
# 4                                       NaN    NaN         NaN
#
#   Vaillant (gas-fired combination boiler from 2008, in ownership)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 1130 columns]

# %%
sum =df.isna().sum()
pd.set_option('display.max_rows', sum.shape[0]+1)
#df1.head()

# %%
#drop when more than X nan value in the colum
df1 = df.dropna(axis=1,thresh=200)
#1200 => 16 columns
#1600 => 46 columns (Harry:which look appropriate for our dataset, as you can see visually,
#                    after cell AV on the sheet, blank column start)
df1.head()
# Out:
#                   Acceptance Annual meeting              Asking price  \
# 0  Available in consultation             No    € 415,000 kosten koper
# 1  Available in consultation            NaN    € 505,000 vrij op naam
# 2  Available in consultation            Yes  € 1,000,000 kosten koper
# 3  Available in consultation            NaN  € 1,098,000 kosten koper
# 4  Available in consultation            NaN    € 417,000 vrij op naam
#
#   Asking price per m² Building insurance    Building type  \
# 0             € 3,402                 No  Resale property
# 1             € 6,733                NaN     New property
# 2             € 5,682                Yes  Resale property
# 3             € 5,779                NaN  Resale property
# 4             € 5,024                NaN     New property
#
#              Energy label Exterior space attached to the building  \
# 0  A What does this mean?                                   17 m²
# 1                     NaN                                   12 m²
# 2  A What does this mean?                                     NaN
# 3  G What does this mean?                                   10 m²
# 4                     NaN                                     NaN
#
#                                           Facilities  \
# 0            Mechanical ventilation and sliding door
# 1                                           Elevator
# 2  Alarm installation, elevator, mechanical venti...
# 3                                        Electricity
# 4                                                NaN
#
#                                       Garden  ...  \
# 0                                Sun terrace  ...
# 1                                        NaN  ...
# 2                                        NaN  ...
# 3  Back garden, front garden and side garden  ...
# 4                                        NaN  ...
#
#                                  Back garden Balcony/roof garden  \
# 0                                        NaN                 NaN
# 1                                        NaN                 NaN
# 2                                        NaN                 NaN
# 3  195 m² (15 meter deep and 13 meter broad)     Balcony present
# 4                                        NaN                 NaN
#
#   Bathroom facilities                CH boiler  \
# 0                 NaN                      NaN
# 1                 NaN                      NaN
# 2                 NaN                      NaN
# 3                Bath  Gas-fired, in ownership
# 4                 NaN                      NaN
#
#                                     Garden location  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3  Located at the northwest accessible via the rear
# 4                                               NaN
#
#                              Kind of house               Number of bath rooms  \
# 0                                      NaN                                NaN
# 1                                      NaN                                NaN
# 2                                      NaN                                NaN
# 3  Desirable residence/villa, corner house  1 bathroom and 2 separate toilets
# 4                                      NaN                                NaN
#
#   Plot size External storage space Specific
# 0       NaN                    NaN      NaN
# 1       NaN                    NaN      NaN
# 2       NaN                    NaN      NaN
# 3    378 m²                    NaN      NaN
# 4       NaN                    NaN      NaN
#
# [5 rows x 45 columns]

# %%
#drop when more than X nan value in a raw
df2 = df1.dropna(thresh=20)
#10 => 1440 over 1686 originaly
#15 => 1423
#20 => 1394 (Harry: I think we should take this one, with small calculation in the excel sheet starting  
#                    at column AT (46) until the end AAL (350) 350-46=304  1686-304=1382 )
#25 => 1161
#30 => 935
cols_to_check = ['Energy label','Listed since','External storage space','Located at',
                 'VVE (Owners Association) contribution','Volume in cubic meters','Provisional energy label']



#find a way to remove "?" for: Provisional energy label & Energy label
#df2[cols_to_check] = df2[cols_to_check].replace({'?':''}, regex=True) 

#check columns: Listed since & Back garden

#check: number of rooms :3 rooms (2 bedrooms) create two column (room&bedroom)??
#check: number of bathrooms :3 rooms (2 bedrooms) create two column (room&bedroom)??

df2[cols_to_check] = df2[cols_to_check].replace({'€':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'kosten koper':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'vrij op naam':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'m²':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'What does this mean?':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'months':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'floor':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'th':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'nd':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'rd':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'st':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'floor':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'weeks':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'Today':'0'}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'weeks':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'per':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'month':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'mon':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'Not available':''}, regex=True)






df2['Asking price'] = df2['Asking price'].str.replace(r'\D', '')
df2['Exterior space attached to the building'] = df2['Exterior space attached to the building'].str.replace(r'\D', '')
df2['Number of stories'] = df2['Number of stories'].str.replace(r'\D', '')
df2['Asking price per m²'] = df2['Asking price per m²'].str.replace(r'\D', '')
df2['Living area'] = df2['Living area'].str.replace(r'\D', '')
df2['Plot size'] = df2['Plot size'].str.replace(r'\D', '')
df2['External storage space'] = df2['External storage space'].str.replace(r'\D', '')
df2['Volume in cubic meters'] = df2['Volume in cubic meters'].str.replace(r'\D', '')


df2['Energy label'] = df2['Energy label'].replace({r"\?":" "}, regex=True)
df2['Provisional energy label'] = df2['Provisional energy label'].replace({r"\?":""}, regex=True)

df2['Number of rooms'] = df2['Number of rooms'].replace({r"\(":","}, regex=True)
df2['Number of rooms'] = df2['Number of rooms'].replace({r"\)":""}, regex=True)
df2['Number of rooms'] = df2['Number of rooms'].replace({'rooms':''}, regex=True)
df2['Number of rooms'] = df2['Number of rooms'].replace({'bedrooms':''}, regex=True)
df2['Number of rooms'] = df2['Number of rooms'].replace({'bedroom':''}, regex=True)
df2['Number of rooms'] = df2['Number of rooms'].replace({'bed':''}, regex=True)
df2['Number of rooms'] = df2['Number of rooms'].replace({'room':''}, regex=True)

df2['Number of bath rooms'] = df2['Number of bath rooms'].replace({'bathrooms':''}, regex=True)
df2['Number of bath rooms'] = df2['Number of bath rooms'].replace({'bathroom':''}, regex=True)
df2['Number of bath rooms'] = df2['Number of bath rooms'].replace({'and':','}, regex=True)
df2['Number of bath rooms'] = df2['Number of bath rooms'].replace({'separate toilets':''}, regex=True)
df2['Number of bath rooms'] = df2['Number of bath rooms'].replace({'separate toilet':''}, regex=True)
df2['Energy label'] = df2['Energy label'].replace({'Not required':''}, regex=True)

df2['Listed since'] = df2['Listed since'].replace({'March 1, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 2, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 3, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 4, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 5, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 6, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 7, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 8, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 9, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 10, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 11, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 12, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 13, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 14, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 15, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 16, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 17, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 18, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 19, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 20, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 21, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 22, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 23, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 24, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 25, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 26, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 27, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 28, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 29, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 30, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'February 28, 2022':'0'}, regex=True)
#df2['Back garden'] = df2['Back garden'].replace(r"\(.*\)",'')

df2['Energy label'] = df2['Energy label'].replace({r"\.":""}, regex=True)
df2['Energy label'] = df2['Energy label'].str.replace('\d+', '')





print(df2)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#                      Acceptance Annual meeting Asking price  \
# 0     Available in consultation             No       415000
# 1     Available in consultation            NaN       505000
# 2     Available in consultation            Yes      1000000
# 3     Available in consultation            NaN      1098000
# 5     Available in consultation            NaN      1995000
# ...                         ...            ...          ...
# 1679  Available in consultation            Yes       185000
# 1680  Available in consultation            Yes       289000
# 1681  Available in consultation            NaN       550000
# 1683  Available in consultation            Yes       389500
# 1684  Available in consultation            Yes       350000
#
#      Asking price per m² Building insurance    Building type Energy label  \
# 0                   3402                 No  Resale property          A
# 1                   6733                NaN     New property          NaN
# 2                   5682                Yes  Resale property          A
# 3                   5779                NaN  Resale property          G
# 5                   4038                NaN  Resale property          E
# ...                  ...                ...              ...          ...
# 1679                4512                 No  Resale property          F
# 1680                3322                Yes  Resale property         B
# 1681                4911                NaN     New property          NaN
# 1683                4809                Yes  Resale property          D
# 1684                4861                Yes  Resale property          A
#
#      Exterior space attached to the building  \
# 0                                         17
# 1                                         12
# 2                                        NaN
# 3                                         10
# 5                                        NaN
# ...                                      ...
# 1679                                       5
# 1680                                       7
# 1681                                     NaN
# 1683                                      11
# 1684                                       6
#
#                                              Facilities  \
# 0               Mechanical ventilation and sliding door
# 1                                              Elevator
# 2     Alarm installation, elevator, mechanical venti...
# 3                                           Electricity
# 5                                           Electricity
# ...                                                 ...
# 1679                                                NaN
# 1680  Elevator, passive ventilation system and TV vi...
# 1681  Balanced ventilation system, outdoor awning, o...
# 1683                                                NaN
# 1684  Mechanical ventilation, passive ventilation sy...
#
#                                          Garden  ...  \
# 0                                   Sun terrace  ...
# 1                                           NaN  ...
# 2                                           NaN  ...
# 3     Back garden, front garden and side garden  ...
# 5                  Back garden and front garden  ...
# ...                                         ...  ...
# 1679                                Back garden  ...
# 1680                                        NaN  ...
# 1681                                        NaN  ...
# 1683                                        NaN  ...
# 1684                                        NaN  ...
#
#                                        Back garden Balcony/roof garden  \
# 0                                              NaN                 NaN
# 1                                              NaN                 NaN
# 2                                              NaN                 NaN
# 3        195 m² (15 meter deep and 13 meter broad)     Balcony present
# 5     181 m² (23,5 meter deep and 7,7 meter broad)     Balcony present
# ...                                            ...                 ...
# 1679     45 m² (10 meter deep and 4,5 meter broad)                 NaN
# 1680                                           NaN     Balcony present
# 1681                                           NaN                 NaN
# 1683                                           NaN     Balcony present
# 1684                                           NaN     Balcony present
#
#      Bathroom facilities                                          CH boiler  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                   Bath                            Gas-fired, in ownership
# 5                    NaN  HR ketel (gas-fired combination boiler from 20...
# ...                  ...                                                ...
# 1679   Shower and toilet                                                NaN
# 1680                 NaN                                                NaN
# 1681                 NaN                                                NaN
# 1683                 NaN  Gas-fired combination boiler from 2021, in own...
# 1684                 NaN  Remeha HR (gas-fired combination boiler from 2...
#
#                                        Garden location  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3     Located at the northwest accessible via the rear
# 5                                  Located at the west
# ...                                                ...
# 1679                              Located at the south
# 1680                                               NaN
# 1681                                               NaN
# 1683                                               NaN
# 1684                                               NaN
#
#                                 Kind of house Number of bath rooms Plot size  \
# 0                                         NaN                  NaN       NaN
# 1                                         NaN                  NaN       NaN
# 2                                         NaN                  NaN       NaN
# 3     Desirable residence/villa, corner house              1  , 2        378
# 5        Desirable residence/villa, row house                   5        400
# ...                                       ...                  ...       ...
# 1679                                      NaN                   1        NaN
# 1680                                      NaN              1  , 1        NaN
# 1681                                      NaN              1  , 1        NaN
# 1683                                      NaN              1  , 1        NaN
# 1684                                      NaN              1  , 1        NaN
#
#      External storage space                                           Specific
# 0                       NaN                                                NaN
# 1                       NaN                                                NaN
# 2                       NaN                                                NaN
# 3                       NaN                                                NaN
# 5                         6  Protected townscape or village view (permit ne...
# ...                     ...                                                ...
# 1679                      8                                                NaN
# 1680                      3                                                NaN
# 1681                    NaN                                                NaN
# 1683                    NaN                                                NaN
# 1684                    NaN                                                NaN
#
# [1316 rows x 45 columns]
# <ipython-input-249-c514f1ac9b65>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Asking price'] = df2['Asking price'].str.replace(r'\D', '')
# <ipython-input-249-c514f1ac9b65>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Exterior space attached to the building'] = df2['Exterior space attached to the building'].str.replace(r'\D', '')
# <ipython-input-249-c514f1ac9b65>:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of stories'] = df2['Number of stories'].str.replace(r'\D', '')
# <ipython-input-249-c514f1ac9b65>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Asking price per m²'] = df2['Asking price per m²'].str.replace(r'\D', '')
# <ipython-input-249-c514f1ac9b65>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Living area'] = df2['Living area'].str.replace(r'\D', '')
# <ipython-input-249-c514f1ac9b65>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Plot size'] = df2['Plot size'].str.replace(r'\D', '')
# <ipython-input-249-c514f1ac9b65>:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['External storage space'] = df2['External storage space'].str.replace(r'\D', '')
# <ipython-input-249-c514f1ac9b65>:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Volume in cubic meters'] = df2['Volume in cubic meters'].str.replace(r'\D', '')
# <ipython-input-249-c514f1ac9b65>:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Energy label'] = df2['Energy label'].replace({r"\?":" "}, regex=True)
# <ipython-input-249-c514f1ac9b65>:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Provisional energy label'] = df2['Provisional energy label'].replace({r"\?":""}, regex=True)
# <ipython-input-249-c514f1ac9b65>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of rooms'] = df2['Number of rooms'].replace({r"\(":","}, regex=True)
# <ipython-input-249-c514f1ac9b65>:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of rooms'] = df2['Number of rooms'].replace({r"\)":""}, regex=True)
# <ipython-input-249-c514f1ac9b65>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of rooms'] = df2['Number of rooms'].replace({'rooms':''}, regex=True)
# <ipython-input-249-c514f1ac9b65>:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of rooms'] = df2['Number of rooms'].replace({'bedrooms':''}, regex=True)
# <ipython-input-249-c514f1ac9b65>:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of rooms'] = df2['Number of rooms'].replace({'bedroom':''}, regex=True)
# <ipython-input-249-c514f1ac9b65>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of rooms'] = df2['Number of rooms'].replace({'bed':''}, regex=True)
# <ipython-input-249-c514f1ac9b65>:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of rooms'] = df2['Number of rooms'].replace({'room':''}, regex=True)
# <ipython-input-249-c514f1ac9b65>:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of bath rooms'] = df2['Number of bath rooms'].replace({'bathrooms':''}, regex=True)
# <ipython-input-249-c514f1ac9b65>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of bath rooms'] = df2['Number of bath rooms'].replace({'bathroom':''}, regex=True)
# <ipython-input-249-c514f1ac9b65>:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of bath rooms'] = df2['Number of bath rooms'].replace({'and':','}, regex=True)
# <ipython-input-249-c514f1ac9b65>:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of bath rooms'] = df2['Number of bath rooms'].replace({'separate toilets':''}, regex=True)
# <ipython-input-249-c514f1ac9b65>:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of bath rooms'] = df2['Number of bath rooms'].replace({'separate toilet':''}, regex=True)
# <ipython-input-249-c514f1ac9b65>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Energy label'] = df2['Energy label'].replace({'Not required':''}, regex=True)
# <ipython-input-249-c514f1ac9b65>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 1, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 2, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 3, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 4, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 5, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 6, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 7, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 8, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 9, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 10, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 11, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 12, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 13, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 14, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 15, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 16, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 17, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 18, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 19, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 20, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 21, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 22, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 23, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 24, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 25, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 26, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 27, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 28, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 29, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 30, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'February 28, 2022':'0'}, regex=True)
# <ipython-input-249-c514f1ac9b65>:108: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Energy label'] = df2['Energy label'].replace({r"\.":""}, regex=True)
# <ipython-input-249-c514f1ac9b65>:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Energy label'] = df2['Energy label'].str.replace('\d+', '')

# %%
df2.rename(columns={'Number of rooms': 'rooms'}, inplace=True)
df2.rooms.str.split(expand=True,)
df2[['rooms','bedroom']] = df2.rooms.str.split(",",expand=True)

df2.rename(columns={'Number of bath rooms': 'bathrooms'}, inplace=True)
df2.bathrooms.str.split(expand=True,)
df2[['bathrooms','toilet']] = df2.bathrooms.str.split(",",expand=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df2.to_csv('rott.csv')
