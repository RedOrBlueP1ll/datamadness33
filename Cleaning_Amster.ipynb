# %%
import seaborn as sns
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import zipfile

# %%
df = pd.read_csv("amsterdam_real_estate_final.csv")
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.head()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (53,55,57,58,59,64,66,69,72,78,86,87,89,90,92,93,95,96,97,99,102,103,104,106,109,112,114,117,118,119,120,132,134,135,138,139,140,145,146,152,153,154,155,157,158,160,162,163,164,165,166,168,169,170,172,176,178,179,180,181,182,188,189,190,193,195,198,199,200,201,202,203,204,205,206,208,209,210,214,215,216,217,218,219,220,221,222,223,224,229,232,233,235,236,237,238,239,240,242,243,244,246,247,249,251,252,254,255,256,258,262,263,264,267,268,269,270,273,275,277,281,282,283,284,285,286,288,289,290,291,292,294,295,296,297,298,299,300,301,302,303,305,308,309,310,311,312,313,315,317,318,320,321,322,323,328,329,331,334,339,342,344,345,346,348,351,354,358,359,360,361,362,364,365,366,367,368,369,370,371,372,373,374,375,376,377,378,379,380,381,382,383,384,385,386,387,388,389,390,391,392,393,394,395,396,397,398,399,400,401,402,403,404,405,406,407,408,409,410,411,412,413,414,415,416,417,418,419,420,421,422,423,424,425,426,427,428,429,430,431,432,433,434,435,436,437,438,439,440,441,442,443,444,445,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506,507,508,509,510,511,512,513,514,515,516,517,518,519,520,521,522,523,524,525,526,527,528,529,530,531,532,533,534,535,536,537,538,539,540,541,542,543,544,545,546,547,548,549,550,551,552,553,554,555,556,557,558,559,560,561,562,563,564,565,566,567,568,569,570,571,572,573,574,575,576,577,578,579,580,581,582,583,584,585,586,587,588,589,590,591,592,593,594,595,596,597,598,599,600,601,602,603,604,605,606,607,608,609,610,611,612,613,614,615,616,617) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                   Acceptance              Asking price Asking price per m²  \
# 0  Available in consultation  € 1,740,000 kosten koper             € 6,374
# 1  Available in consultation    € 550,000 kosten koper             € 5,140
# 2  Available in consultation    € 800,000 kosten koper             € 6,504
# 3                        NaN                       NaN                 NaN
# 4                        NaN    € 545,000 vrij op naam             € 6,124
#
#              Bathroom facilities    Building type               Energy label  \
# 0  Bath, 2 showers and 2 toilets  Resale property     F What does this mean?
# 1                Bath and shower  Resale property                        NaN
# 2                            NaN  Resale property     F What does this mean?
# 3                            NaN              NaN                        NaN
# 4                         Shower     New property  A+++ What does this mean?
#
#   Exterior space attached to the building  \
# 0                                   10 m²
# 1                                   12 m²
# 2                                    4 m²
# 3                                     NaN
# 4                                   22 m²
#
#                                     Facilities        Garden  \
# 0  Passive ventilation system and TV via cable  Patio/atrium
# 1          Elevator and mechanical ventilation           NaN
# 2                                          NaN           NaN
# 3                                          NaN           NaN
# 4                                          NaN   Sun terrace
#
#             Heating  ... 41 m² 82 m² 929 m³ Achtertuin  \
# 0       Gas heaters  ...   NaN   NaN    NaN        NaN
# 1         CH boiler  ...   NaN   NaN    NaN        NaN
# 2         CH boiler  ...   NaN   NaN    NaN        NaN
# 3               NaN  ...   NaN   NaN    NaN        NaN
# 4  District heating  ...   NaN   NaN    NaN        NaN
#
#   Betaald parkeren en parkeervergunningen D Wat betekent dit?  \
# 0                                     NaN                 NaN
# 1                                     NaN                 NaN
# 2                                     NaN                 NaN
# 3                                     NaN                 NaN
# 4                                     NaN                 NaN
#
#   Dakterras aanwezig, balkon aanwezig en frans balkon aanwezig  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Gelegen op het westen HR-107-ketel (gas gestookt combiketel, eigendom)  \
# 0                   NaN                                              NaN
# 1                   NaN                                              NaN
# 2                   NaN                                              NaN
# 3                   NaN                                              NaN
# 4                   NaN                                              NaN
#
#   Mechanische ventilatie en TV kabel
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
# [5 rows x 613 columns]

# %%
sum =df.isna().sum()
pd.set_option('display.max_rows', sum.shape[0]+1)
#df1.head()

# %%
#drop when more than X nan value in the colum
df1 = df.dropna(axis=1,thresh=200)
#1200 => 16 columns
#1600 => 46 columns (Harry: same as rotterdam but here 49 columns)
df1.head()
# Out:
#                   Acceptance              Asking price Asking price per m²  \
# 0  Available in consultation  € 1,740,000 kosten koper             € 6,374
# 1  Available in consultation    € 550,000 kosten koper             € 5,140
# 2  Available in consultation    € 800,000 kosten koper             € 6,504
# 3                        NaN                       NaN                 NaN
# 4                        NaN    € 545,000 vrij op naam             € 6,124
#
#              Bathroom facilities    Building type               Energy label  \
# 0  Bath, 2 showers and 2 toilets  Resale property     F What does this mean?
# 1                Bath and shower  Resale property                        NaN
# 2                            NaN  Resale property     F What does this mean?
# 3                            NaN              NaN                        NaN
# 4                         Shower     New property  A+++ What does this mean?
#
#   Exterior space attached to the building  \
# 0                                   10 m²
# 1                                   12 m²
# 2                                    4 m²
# 3                                     NaN
# 4                                   22 m²
#
#                                     Facilities        Garden  \
# 0  Passive ventilation system and TV via cable  Patio/atrium
# 1          Elevator and mechanical ventilation           NaN
# 2                                          NaN           NaN
# 3                                          NaN           NaN
# 4                                          NaN   Sun terrace
#
#             Heating  ... Reserve fund present Shed / storage  \
# 0       Gas heaters  ...                  NaN            NaN
# 1         CH boiler  ...                  Yes    Storage box
# 2         CH boiler  ...                  Yes            NaN
# 3               NaN  ...                  NaN            NaN
# 4  District heating  ...                   No            NaN
#
#                        Type apartment VVE (Owners Association) contribution  \
# 0                                 NaN                                   NaN
# 1             Maisonnette (apartment)                                   NaN
# 2      Upstairs apartment (apartment)                    € 232.00 per month
# 3                                 NaN                                   NaN
# 4  Ground-floor apartment (apartment)                                   NaN
#
#                     Quality marks  Service charges       Type of garage  \
# 0                             NaN              NaN                  NaN
# 1                             NaN              NaN                  NaN
# 2                             NaN              NaN                  NaN
# 3                             NaN              NaN                  NaN
# 4  Woningborg garantiecertificaat  € 133 per month  Underground parking
#
#   Other space inside the building Garden location Back garden
# 0                             NaN             NaN         NaN
# 1                             NaN             NaN         NaN
# 2                             NaN             NaN         NaN
# 3                             NaN             NaN         NaN
# 4                             NaN             NaN         NaN
#
# [5 rows x 47 columns]

# %%
df2 = df1.dropna(thresh=20)
#print(df2)

# %%
cols_to_check = ['Energy label','Listed since','External storage space','Located at',
                 'VVE (Owners Association) contribution','Volume in cubic meters',
                 'Provisional energy label','Year of construction','Service charges',
                 'Other space inside the building']



df2[cols_to_check] = df2[cols_to_check].replace({'€':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'kosten koper':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'vrij op naam':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'m²':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'What does this mean?':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'months':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'floor':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'th':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'nd':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'rd':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'st':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'floor':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'weeks':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'Today':'0'}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'weeks':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'per':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'month':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'mon':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'Not available':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'After ':''}, regex=True)
df2[cols_to_check] = df2[cols_to_check].replace({'Before ':''}, regex=True)




df2['Asking price'] = df2['Asking price'].str.replace(r'\D', '')
df2['Exterior space attached to the building'] = df2['Exterior space attached to the building'].str.replace(r'\D', '')
df2['Number of stories'] = df2['Number of stories'].str.replace(r'\D', '')
df2['Asking price per m²'] = df2['Asking price per m²'].str.replace(r'\D', '')
df2['Living area'] = df2['Living area'].str.replace(r'\D', '')
df2['Plot size'] = df2['Plot size'].str.replace(r'\D', '')
df2['External storage space'] = df2['External storage space'].str.replace(r'\D', '')
df2['Volume in cubic meters'] = df2['Volume in cubic meters'].str.replace(r'\D', '')



df2['Building type'] = df2['Building type'].replace({' property':''}, regex=True)


df2['Number of rooms'] = df2['Number of rooms'].replace({r"\(":","}, regex=True)
df2['Number of rooms'] = df2['Number of rooms'].replace({r"\)":""}, regex=True)
df2['Number of rooms'] = df2['Number of rooms'].replace({'rooms':''}, regex=True)
df2['Number of rooms'] = df2['Number of rooms'].replace({'bedrooms':''}, regex=True)
df2['Number of rooms'] = df2['Number of rooms'].replace({'bedroom':''}, regex=True)
df2['Number of rooms'] = df2['Number of rooms'].replace({'bed':''}, regex=True)
df2['Number of rooms'] = df2['Number of rooms'].replace({'room':''}, regex=True)

df2['Number of bath rooms'] = df2['Number of bath rooms'].replace({'bathrooms':''}, regex=True)
df2['Number of bath rooms'] = df2['Number of bath rooms'].replace({'bathroom':''}, regex=True)
df2['Number of bath rooms'] = df2['Number of bath rooms'].replace({'and':','}, regex=True)
df2['Number of bath rooms'] = df2['Number of bath rooms'].replace({'separate toilets':''}, regex=True)
df2['Number of bath rooms'] = df2['Number of bath rooms'].replace({'separate toilet':''}, regex=True)


df2['Energy label'] = df2['Energy label'].replace({'Not required':''}, regex=True)
df2['Provisional energy label'] = df2['Provisional energy label'].replace({r"\?":""}, regex=True) 
df2['Energy label'] = df2['Energy label'].replace({r"\?":" "}, regex=True)



df2['Listed since'] = df2['Listed since'].replace({'March 1, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 2, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 3, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 4, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 5, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 6, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 7, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 8, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 9, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 10, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 11, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 12, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 13, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 14, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 15, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 16, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 17, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 18, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 19, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 20, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 21, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 22, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 23, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 24, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 25, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 26, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 27, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 28, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 29, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'March 30, 2022':'0'}, regex=True)
df2['Listed since'] = df2['Listed since'].replace({'February 28, 2022':'0'}, regex=True)

df2['Energy label'] = df2['Energy label'].replace({r"\.":""}, regex=True)
df2['Energy label'] = df2['Energy label'].str.replace('\d+', '')

#df2['Back garden'] = df2['Back garden'].replace(r"\(.*\)",'')


print(df2)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#                      Acceptance Asking price Asking price per m²  \
# 0     Available in consultation      1740000                6374
# 1     Available in consultation       550000                5140
# 2     Available in consultation       800000                6504
# 4                           NaN       545000                6124
# 5     Available in consultation      4350000               11417
# ...                         ...          ...                 ...
# 2012  Available in consultation      1550000               10993
# 2013  Available in consultation       500000                5556
# 2014  Available in consultation       325000                4452
# 2016  Available in consultation       450000                6618
# 2017  Available in consultation      1800000                9730
#
#                 Bathroom facilities Building type Energy label  \
# 0     Bath, 2 showers and 2 toilets        Resale          F
# 1                   Bath and shower        Resale          NaN
# 2                               NaN        Resale          F
# 4                            Shower           New       A+++
# 5                               NaN           New          NaN
# ...                             ...           ...          ...
# 2012        2 showers and 2 toilets        Resale
# 2013                         Shower        Resale          A
# 2014                           Bath        Resale          NaN
# 2016                         Shower        Resale          C
# 2017                            NaN           New          NaN
#
#      Exterior space attached to the building  \
# 0                                         10
# 1                                         12
# 2                                          4
# 4                                         22
# 5                                        110
# ...                                      ...
# 2012                                     NaN
# 2013                                       8
# 2014                                     NaN
# 2016                                       4
# 2017                                      28
#
#                                        Facilities        Garden  \
# 0     Passive ventilation system and TV via cable  Patio/atrium
# 1             Elevator and mechanical ventilation           NaN
# 2                                             NaN           NaN
# 4                                             NaN   Sun terrace
# 5                                             NaN   Sun terrace
# ...                                           ...           ...
# 2012                                          NaN           NaN
# 2013                                  Electricity           NaN
# 2014                       Mechanical ventilation   Back garden
# 2016  Passive ventilation system and TV via cable           NaN
# 2017                                  Electricity           NaN
#
#                                             Heating  ... Reserve fund present  \
# 0                                       Gas heaters  ...                  NaN
# 1                                         CH boiler  ...                  Yes
# 2                                         CH boiler  ...                  Yes
# 4                                  District heating  ...                   No
# 5                            Complete floor heating  ...                  NaN
# ...                                             ...  ...                  ...
# 2012                                      CH boiler  ...                  NaN
# 2013    District heating and complete floor heating  ...                  Yes
# 2014                                      CH boiler  ...                  Yes
# 2016                                      CH boiler  ...                  Yes
# 2017  Complete floor heating and heat recovery unit  ...                  NaN
#
#               Shed / storage  \
# 0                        NaN
# 1                Storage box
# 2                        NaN
# 4                        NaN
# 5                Storage box
# ...                      ...
# 2012                     NaN
# 2013                Built-in
# 2014             Storage box
# 2016  Attached brick storage
# 2017             Storage box
#
#                                          Type apartment  \
# 0                                                   NaN
# 1                               Maisonnette (apartment)
# 2                        Upstairs apartment (apartment)
# 4                    Ground-floor apartment (apartment)
# 5                                 Penthouse (apartment)
# ...                                                 ...
# 2012                                                NaN
# 2013                     Upstairs apartment (apartment)
# 2014                             Ground-floor apartment
# 2016  Apartment with shared street entrance (apartment)
# 2017                              Mezzanine (apartment)
#
#      VVE (Owners Association) contribution                   Quality marks  \
# 0                                      NaN                             NaN
# 1                                      NaN                             NaN
# 2                                 232.00                               NaN
# 4                                      NaN  Woningborg garantiecertificaat
# 5                                      NaN                             NaN
# ...                                    ...                             ...
# 2012                                   NaN                             NaN
# 2013                              117.00                               NaN
# 2014                              111.03                               NaN
# 2016                                   NaN                             NaN
# 2017                                   NaN         SWK garantiecertificaat
#
#      Service charges       Type of garage Other space inside the building  \
# 0                NaN                  NaN                             NaN
# 1                NaN                  NaN                             NaN
# 2                NaN                  NaN                             NaN
# 4              133    Underground parking                             NaN
# 5                NaN                  NaN                             NaN
# ...              ...                  ...                             ...
# 2012             NaN                  NaN                             NaN
# 2013             NaN                  NaN                             NaN
# 2014             NaN                  NaN                             NaN
# 2016           104                    NaN                             NaN
# 2017             NaN  Underground parking                             NaN
#
#            Garden location                                    Back garden
# 0                      NaN                                            NaN
# 1                      NaN                                            NaN
# 2                      NaN                                            NaN
# 4                      NaN                                            NaN
# 5                      NaN                                            NaN
# ...                    ...                                            ...
# 2012                   NaN                                            NaN
# 2013                   NaN                                            NaN
# 2014  Located at the south  72 m² (5,02 meter deep and 14,27 meter broad)
# 2016                   NaN                                            NaN
# 2017                   NaN                                            NaN
#
# [1899 rows x 47 columns]
# <ipython-input-17-15e27b21581f>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Asking price'] = df2['Asking price'].str.replace(r'\D', '')
# <ipython-input-17-15e27b21581f>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Exterior space attached to the building'] = df2['Exterior space attached to the building'].str.replace(r'\D', '')
# <ipython-input-17-15e27b21581f>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of stories'] = df2['Number of stories'].str.replace(r'\D', '')
# <ipython-input-17-15e27b21581f>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Asking price per m²'] = df2['Asking price per m²'].str.replace(r'\D', '')
# <ipython-input-17-15e27b21581f>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Living area'] = df2['Living area'].str.replace(r'\D', '')
# <ipython-input-17-15e27b21581f>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Plot size'] = df2['Plot size'].str.replace(r'\D', '')
# <ipython-input-17-15e27b21581f>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['External storage space'] = df2['External storage space'].str.replace(r'\D', '')
# <ipython-input-17-15e27b21581f>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Volume in cubic meters'] = df2['Volume in cubic meters'].str.replace(r'\D', '')
# <ipython-input-17-15e27b21581f>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Building type'] = df2['Building type'].replace({' property':''}, regex=True)
# <ipython-input-17-15e27b21581f>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of rooms'] = df2['Number of rooms'].replace({r"\(":","}, regex=True)
# <ipython-input-17-15e27b21581f>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of rooms'] = df2['Number of rooms'].replace({r"\)":""}, regex=True)
# <ipython-input-17-15e27b21581f>:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of rooms'] = df2['Number of rooms'].replace({'rooms':''}, regex=True)
# <ipython-input-17-15e27b21581f>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of rooms'] = df2['Number of rooms'].replace({'bedrooms':''}, regex=True)
# <ipython-input-17-15e27b21581f>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of rooms'] = df2['Number of rooms'].replace({'bedroom':''}, regex=True)
# <ipython-input-17-15e27b21581f>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of rooms'] = df2['Number of rooms'].replace({'bed':''}, regex=True)
# <ipython-input-17-15e27b21581f>:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of rooms'] = df2['Number of rooms'].replace({'room':''}, regex=True)
# <ipython-input-17-15e27b21581f>:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of bath rooms'] = df2['Number of bath rooms'].replace({'bathrooms':''}, regex=True)
# <ipython-input-17-15e27b21581f>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of bath rooms'] = df2['Number of bath rooms'].replace({'bathroom':''}, regex=True)
# <ipython-input-17-15e27b21581f>:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of bath rooms'] = df2['Number of bath rooms'].replace({'and':','}, regex=True)
# <ipython-input-17-15e27b21581f>:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of bath rooms'] = df2['Number of bath rooms'].replace({'separate toilets':''}, regex=True)
# <ipython-input-17-15e27b21581f>:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Number of bath rooms'] = df2['Number of bath rooms'].replace({'separate toilet':''}, regex=True)
# <ipython-input-17-15e27b21581f>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Energy label'] = df2['Energy label'].replace({'Not required':''}, regex=True)
# <ipython-input-17-15e27b21581f>:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Provisional energy label'] = df2['Provisional energy label'].replace({r"\?":""}, regex=True)
# <ipython-input-17-15e27b21581f>:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Energy label'] = df2['Energy label'].replace({r"\?":" "}, regex=True)
# <ipython-input-17-15e27b21581f>:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 1, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 2, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 3, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 4, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 5, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 6, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 7, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 8, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 9, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 10, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 11, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 12, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 13, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 14, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 15, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 16, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 17, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 18, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 19, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 20, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 21, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 22, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 23, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 24, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 25, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 26, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 27, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 28, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 29, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'March 30, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Listed since'] = df2['Listed since'].replace({'February 28, 2022':'0'}, regex=True)
# <ipython-input-17-15e27b21581f>:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Energy label'] = df2['Energy label'].replace({r"\.":""}, regex=True)
# <ipython-input-17-15e27b21581f>:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Energy label'] = df2['Energy label'].str.replace('\d+', '')

# %%
df2.rename(columns={'Number of rooms': 'rooms'}, inplace=True)
df2.rooms.str.split(expand=True,)
df2[['rooms','bedroom']] = df2.rooms.str.split(",",expand=True)

df2.rename(columns={'Number of bath rooms': 'bathrooms'}, inplace=True)
df2.bathrooms.str.split(expand=True,)
df2[['bathrooms','toilet']] = df2.bathrooms.str.split(",",expand=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df2.rename(columns={'Periodic contribution': 'Periodic_contribution'}, inplace=True)
df2.Periodic_contribution.str.split(expand=True,)
df2[['Periodic_contribution','price_contribution']] = df2.Periodic_contribution.str.split(r"\(",expand=True)
df2['price_contribution'] = df2['price_contribution'].replace({'€':''}, regex=True)
df2['price_contribution'] = df2['price_contribution'].replace({'per month':''}, regex=True)
df2['price_contribution'] = df2['price_contribution'].replace({r"\)":''}, regex=True)
# Out:
# <ipython-input-19-5389aeb6326d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['price_contribution'] = df2['price_contribution'].replace({'€':''}, regex=True)
# <ipython-input-19-5389aeb6326d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['price_contribution'] = df2['price_contribution'].replace({'per month':''}, regex=True)
# <ipython-input-19-5389aeb6326d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['price_contribution'] = df2['price_contribution'].replace({r"\)":''}, regex=True)

# %%
df2.rename(columns={'Back garden': 'Back_garden'}, inplace=True)
df2.Back_garden.str.split(expand=True,)
df2[['Back_garden','Back_garden_measure']] = df2.Back_garden.str.split(r"\(",expand=True)
del df2["Back_garden_measure"]
df2['Back_garden'] = df2['Back_garden'].replace({'m²':''}, regex=True)
# Out:
# <ipython-input-20-0ab53631132b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Back_garden'] = df2['Back_garden'].replace({'m²':''}, regex=True)

# %%
df2['Building type'] = df2['Building type'].replace({'property':''}, regex=True)
df2['Year of construction'] = df2['Year of construction'].replace({'After':''}, regex=True)
df2['Year of construction'] = df2['Year of construction'].replace({'Before':''}, regex=True)
df2['Balcony/roof garden'] = df2['Balcony/roof garden'].replace({'present':''}, regex=True)
df2['Garden location'] = df2['Garden location'].replace({'Located at the':''}, regex=True)
df2['Garden location'] = df2['Garden location'].replace({'accessible via the rear':''}, regex=True)
df2['Type of roof'] = df2['Type of roof'].replace({'roof':''}, regex=True)
df2['Type of roof'] = df2['Type of roof'].replace({'roofing':''}, regex=True)
# Out:
# <ipython-input-21-a7e68de2148d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Building type'] = df2['Building type'].replace({'property':''}, regex=True)
# <ipython-input-21-a7e68de2148d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Year of construction'] = df2['Year of construction'].replace({'After':''}, regex=True)
# <ipython-input-21-a7e68de2148d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Year of construction'] = df2['Year of construction'].replace({'Before':''}, regex=True)
# <ipython-input-21-a7e68de2148d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Balcony/roof garden'] = df2['Balcony/roof garden'].replace({'present':''}, regex=True)
# <ipython-input-21-a7e68de2148d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Garden location'] = df2['Garden location'].replace({'Located at the':''}, regex=True)
# <ipython-input-21-a7e68de2148d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Garden location'] = df2['Garden location'].replace({'accessible via the rear':''}, regex=True)
# <ipython-input-21-a7e68de2148d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Type of roof'] = df2['Type of roof'].replace({'roof':''}, regex=True)
# <ipython-input-21-a7e68de2148d>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Type of roof'] = df2['Type of roof'].replace({'roofing':''}, regex=True)

# %%
df2.to_csv('Amster.csv')
